# %% [markdown]
# ### Getting Data from Google Places

# %%
#Import Module
import requests

# %%
#Getting Data From Google Places

#All the markets near Green on the Fourth, Minneapolis
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=44.9720,-93.2141&radius=5000&name=market&key=AIzaSyCsE3-ENI_1_2SCjTVIG3Wv2LKbJIIfWCY"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "Aap_uEANGjcwZlEzauTCLEGLciFd6QISRylpRQuUJn4pADH1A8cr9jz4oKytKeD_A3RfeyFeBHzBBmknE65hw-YPYggWFBSrW3heHPB9zGuioYmxEBtpV7X-Y0ryX1Zbn5sb7bf0Zc8dX_ptbQfMt27Y2Zt0K1NKvQw3V7KCxYx7-pX3KhHskRy0GAetdf9zTG4YYPMfCN24ynzuspw86qjKMpi4U0Nm2mI52hNUbBF9nj1ifdH51izQfuZOBIzG8Ysoo1-wyig3cYg73yBGTScZ7ZVeVs1_1hGj_YxVa9KHc4jq1QrwbBCJ22fKamDKmP0cLWbRVDlhDd2TFzumGuNY9LsKPqiaPlM-mjQmct9Kk98B9IxLXpNpZeVoSQtRkhAGqcmTEooj6dj6vBFQEnMnfI5XclCPHOxEU7nlGiKym1YAt9VX4wMFYXA",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.948519,
#                "lng" : -93.260485
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.95018932989272,
#                   "lng" : -93.25941787010728
#                },
#                "southwest" : {
#                   "lat" : 44.94748967010728,
# ...

# %% [markdown]
# ### Getting Data from NDAWN

# %%
#Getting Avg Temp of Fox Station from NDAWN
url2 = "https://ndawn.ndsu.nodak.edu/table.csv?station=93&variable=ddavt&year=2021&ttype=daily&quick_pick=&begin_date=2021-09-01&end_date=2021-09-10"

#response2 = requests.get(url2)

payload={}
headers = {}

response2 = requests.request("GET", url2, headers=headers, data=payload)
print(response2.text)
# Out:
# Data from North Dakota Agricultural Weather Network https://ndawn.ndsu.nodak.edu
# Daily Observation Table for September 1 2021 to September 10 2021
# Flag Definition Line: M - Missing; E - Estimated; N/A - Not Available
# Station Name,Latitude,Longitude,Elevation,Year,Month,Day,Avg Temp,Avg Temp Flag
# ,deg,deg,ft,,,,Degrees F,
# Fox,48.877738,-95.850160,1040,2021,09,01,64.715,
# Fox,48.877738,-95.850160,1040,2021,09,02,63.545,
# Fox,48.877738,-95.850160,1040,2021,09,03,64.796,
# Fox,48.877738,-95.850160,1040,2021,09,04,61.466,
# Fox,48.877738,-95.850160,1040,2021,09,05,57.227,
# Fox,48.877738,-95.850160,1040,2021,09,06,64.202,
# Fox,48.877738,-95.850160,1040,2021,09,07,64.508,
# Fox,48.877738,-95.850160,1040,2021,09,08,58.820,
# Fox,48.877738,-95.850160,1040,2021,09,09,57.143,
# Fox,48.877738,-95.850160,1040,2021,09,10,68.324,
